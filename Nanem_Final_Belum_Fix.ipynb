# %% [markdown]
# <a href="https://colab.research.google.com/github/kimimumemo/nanem/blob/main/Nanem_Final_Belum_Fix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![BackgroundEraser_image.png](data:image/png;base64,...)

# %% [markdown]
# This notebook will walk you through the process of building a Machine Learning model for predicting what type of soil that you scan.
#
# We will classifying four species of soil by using **pre-trained TF2 SavedModel** from TensorFlow Hub for image feature extraction, which we trained on the much larger ImageNet dataset.
#
# Adding new classifier alongside can also be done in which we use the feature extractor ("fine-tuning").

# %% [markdown]
# # Step  1: Install packages

# %%
# !pip install -U tensorflow-addons
# !pip install -q keras
# !pip install split-folders
# !pip install tensorflow-gpu
# Out:
# Requirement already up-to-date: tensorflow-addons in /usr/local/lib/python3.7/dist-packages (0.13.0)
# Requirement already satisfied, skipping upgrade: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Requirement already satisfied: split-folders in /usr/local/lib/python3.7/dist-packages (0.4.3)
# Requirement already satisfied: tensorflow-gpu in /usr/local/lib/python3.7/dist-packages (2.5.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.7.4.3)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.19.5)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.12.4)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.5.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.5.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.36.2)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.12)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.34.1)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.1.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.12.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.5.0.dev2021032900)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.9.2->tensorflow-gpu) (57.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (1.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (0.4.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (1.30.0)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow-gpu) (4.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.5->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow-gpu) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu) (0.4.8)

# %%
# !nvidia-smi
# Out:
# Mon Jun  7 10:00:24 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P0    30W /  70W |    102MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Step 2: Load the dependencies

# %%
import cv2 as cv2
import itertools
import numpy as np
import os
import pandas as pd
import seaborn as sns
import sys
import tensorflow as tf
import tensorflow_hub as hub
import time
import tensorflow_addons as tfa
import uuid
import math

from glob import glob
from IPython.display import clear_output
from keras.utils.np_utils import to_categorical
from matplotlib import pyplot as plt
from PIL import Image
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Step 3: Select the TF2 SavedModel module to use

# %%
module_selection = ("mobilenet_v2_100_224", 224)
handle_base, pixels = module_selection
MODULE_HANDLE ="https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1".format(handle_base)
IMAGE_SIZE = (224, 224)
print("Using {} with input size {}".format(MODULE_HANDLE, IMAGE_SIZE))
# Out:
# Using https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1 with input size (224, 224)

# %%
IMG_SHAPE = (224,224,3)

base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False, 
                                               weights='imagenet')

# %%
base_model.trainable = False

# %% [markdown]
# # Step 4: Import Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
BASE_DATASET_PATH = '/content/drive/MyDrive/download_baru_4-224'

BASE_PATH = '/content/drive/MyDrive'
DATASET_FOLDER = 'download_baru_5'
# OUTPUT_PATH = '/content/drive/MyDrive/output_data_cnn_4'

# %% [markdown]
# # Step 5: See how many of each label we have

# %%
# To know how many picture in the datasets

num_files = 0

for folder in os.listdir(BASE_DATASET_PATH):
  files = os.listdir(os.path.join(BASE_DATASET_PATH, folder))
  # Calculate num files for image every folder
  print("{} folder has {} pictures".format(folder, len(files)))
  num_files += len(files)
print("\nThere are {} pictures in total".format(num_files))
# Out:
# Latosol folder has 398 pictures
# Humus folder has 335 pictures
# Alluvial folder has 354 pictures
# Clay folder has 334 pictures
#
# There are 1421 pictures in total

# %% [markdown]
# # Step 6: Split data to validation and training

# %%
BATCH_SIZE = 32

data_dir = BASE_DATASET_PATH

datagen_kwargs = dict(rescale=1./255, validation_split=.20)
dataflow_kwargs = dict(target_size=IMAGE_SIZE, batch_size=BATCH_SIZE,
                   interpolation="bilinear")

valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    **datagen_kwargs)
valid_generator = valid_datagen.flow_from_directory(
    data_dir, subset="validation", shuffle=False, **dataflow_kwargs)

do_data_augmentation = False

if do_data_augmentation:
  train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
      rotation_range=40,
      horizontal_flip=True,
      width_shift_range=0.2, height_shift_range=0.2,
      shear_range=0.2, zoom_range=0.2,
      **datagen_kwargs)
else:
  train_datagen = valid_datagen
  train_generator = train_datagen.flow_from_directory(
    data_dir, subset="training", shuffle=True, **dataflow_kwargs)
# Out:
# Found 282 images belonging to 4 classes.
# Found 1139 images belonging to 4 classes.

# %% [markdown]
# # Step 7: Build neural network

# %%
model = tf.keras.Sequential([
    # hub.KerasLayer(MODULE_HANDLE, dtype=tf.uint8),
    # hub.KerasLayer(MODULE_HANDLE, trainable=True),
    base_model,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(4, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(0.0001))
])
model.build((None,)+IMAGE_SIZE+(3,))
model.summary()
# opt = tfa.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-4)
model.compile(loss='categorical_hinge', optimizer='adam', metrics=['accuracy'])
# callbacks from tensor
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 62720)             0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 62720)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 250884
# =================================================================
# Total params: 2,508,868
# Trainable params: 250,884
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
 do_fine_tuning = False

# %% [markdown]
# # Step 8: Train neural network using training dataset

# %%
start = time.time()

steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = valid_generator.samples // valid_generator.batch_size
hist = model.fit(
    train_generator,
    epochs=100, steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=validation_steps).history

end = time.time()
print("Total train time: ",(end-start)/60," mins")
# Out:
# Epoch 1/100
# 35/35 [==============================] - 55s 993ms/step - loss: 1.3624 - accuracy: 0.3135 - val_loss: 1.3226 - val_accuracy: 0.3320
# Epoch 2/100
# 35/35 [==============================] - 35s 989ms/step - loss: 1.1779 - accuracy: 0.4074 - val_loss: 1.2387 - val_accuracy: 0.3828
# Epoch 3/100
# 35/35 [==============================] - 34s 982ms/step - loss: 1.0494 - accuracy: 0.4706 - val_loss: 1.1530 - val_accuracy: 0.4258
# Epoch 4/100
# 35/35 [==============================] - 34s 984ms/step - loss: 1.0341 - accuracy: 0.4788 - val_loss: 1.2537 - val_accuracy: 0.3711
# Epoch 5/100
# 35/35 [==============================] - 34s 972ms/step - loss: 1.0488 - accuracy: 0.4779 - val_loss: 1.3220 - val_accuracy: 0.3359
# Epoch 6/100
# 35/35 [==============================] - 34s 982ms/step - loss: 1.0087 - accuracy: 0.4941 - val_loss: 1.0365 - val_accuracy: 0.4844
# Epoch 7/100
# 35/35 [==============================] - 34s 976ms/step - loss: 0.8881 - accuracy: 0.5565 - val_loss: 1.1167 - val_accuracy: 0.4414
# Epoch 8/100
# 35/35 [==============================] - 34s 978ms/step - loss: 0.8851 - accuracy: 0.5574 - val_loss: 1.0016 - val_accuracy: 0.5000
# Epoch 9/100
# 35/35 [==============================] - 34s 976ms/step - loss: 0.8554 - accuracy: 0.5736 - val_loss: 1.0629 - val_accuracy: 0.4688
# Epoch 10/100
# 35/35 [==============================] - 34s 978ms/step - loss: 0.8000 - accuracy: 0.6007 - val_loss: 0.9374 - val_accuracy: 0.5352
# Epoch 11/100
# 35/35 [==============================] - 34s 988ms/step - loss: 0.7441 - accuracy: 0.6278 - val_loss: 0.9198 - val_accuracy: 0.5430
# Epoch 12/100
# 35/35 [==============================] - 35s 995ms/step - loss: 0.7223 - accuracy: 0.6402 - val_loss: 0.9142 - val_accuracy: 0.5430
# Epoch 13/100
# 35/35 [==============================] - 34s 981ms/step - loss: 0.7397 - accuracy: 0.6314 - val_loss: 1.0035 - val_accuracy: 0.5000
# Epoch 14/100
# 35/35 [==============================] - 34s 987ms/step - loss: 0.7212 - accuracy: 0.6423 - val_loss: 0.8763 - val_accuracy: 0.5703
# Epoch 15/100
# 35/35 [==============================] - 39s 1s/step - loss: 0.7027 - accuracy: 0.6522 - val_loss: 0.8747 - val_accuracy: 0.5625
# Epoch 16/100
# 35/35 [==============================] - 34s 977ms/step - loss: 0.6714 - accuracy: 0.6667 - val_loss: 0.9008 - val_accuracy: 0.5547
# Epoch 17/100
# 35/35 [==============================] - 34s 979ms/step - loss: 0.6697 - accuracy: 0.6694 - val_loss: 0.8519 - val_accuracy: 0.5781
# Epoch 18/100
# 35/35 [==============================] - 34s 985ms/step - loss: 0.6717 - accuracy: 0.6676 - val_loss: 0.8486 - val_accuracy: 0.5820
# Epoch 19/100
# 35/35 [==============================] - 34s 973ms/step - loss: 0.6700 - accuracy: 0.6694 - val_loss: 0.8311 - val_accuracy: 0.5898
# Epoch 20/100
# 35/35 [==============================] - 34s 974ms/step - loss: 0.6456 - accuracy: 0.6811 - val_loss: 0.8267 - val_accuracy: 0.5898
# Epoch 21/100
# 35/35 [==============================] - 34s 985ms/step - loss: 0.6421 - accuracy: 0.6829 - val_loss: 0.8841 - val_accuracy: 0.5625
# Epoch 22/100
# 35/35 [==============================] - 35s 992ms/step - loss: 0.6299 - accuracy: 0.6893 - val_loss: 0.8440 - val_accuracy: 0.5820
# Epoch 23/100
# 35/35 [==============================] - 34s 984ms/step - loss: 0.6370 - accuracy: 0.6856 - val_loss: 0.9658 - val_accuracy: 0.5195
# Epoch 24/100
# 35/35 [==============================] - 34s 975ms/step - loss: 0.6665 - accuracy: 0.6712 - val_loss: 0.8354 - val_accuracy: 0.5859
# Epoch 25/100
# 35/35 [==============================] - 34s 981ms/step - loss: 0.6256 - accuracy: 0.6911 - val_loss: 0.8659 - val_accuracy: 0.5742
# Epoch 26/100
# 35/35 [==============================] - 34s 977ms/step - loss: 0.6117 - accuracy: 0.7001 - val_loss: 0.8644 - val_accuracy: 0.5703
# Epoch 27/100
# 35/35 [==============================] - 34s 983ms/step - loss: 0.6379 - accuracy: 0.6856 - val_loss: 0.8197 - val_accuracy: 0.5938
# Epoch 28/100
# 35/35 [==============================] - 34s 982ms/step - loss: 0.6142 - accuracy: 0.6983 - val_loss: 0.8618 - val_accuracy: 0.5742
# Epoch 29/100
# 35/35 [==============================] - 34s 970ms/step - loss: 0.6176 - accuracy: 0.6965 - val_loss: 0.8041 - val_accuracy: 0.6016
# Epoch 30/100
# 35/35 [==============================] - 34s 974ms/step - loss: 0.5973 - accuracy: 0.7082 - val_loss: 0.8364 - val_accuracy: 0.5859
# Epoch 31/100
# 35/35 [==============================] - 34s 981ms/step - loss: 0.6464 - accuracy: 0.6820 - val_loss: 0.9097 - val_accuracy: 0.5508
# Epoch 32/100
# 35/35 [==============================] - 34s 984ms/step - loss: 0.6608 - accuracy: 0.6739 - val_loss: 0.8589 - val_accuracy: 0.5781
# Epoch 33/100
# 35/35 [==============================] - 34s 986ms/step - loss: 0.6683 - accuracy: 0.6703 - val_loss: 0.8487 - val_accuracy: 0.5820
# Epoch 34/100
# 35/35 [==============================] - 34s 977ms/step - loss: 0.6207 - accuracy: 0.6965 - val_loss: 0.8332 - val_accuracy: 0.5898
# Epoch 35/100
# 35/35 [==============================] - 34s 979ms/step - loss: 0.6770 - accuracy: 0.6667 - val_loss: 0.8675 - val_accuracy: 0.5742
# Epoch 36/100
# 35/35 [==============================] - 34s 976ms/step - loss: 0.6206 - accuracy: 0.6965 - val_loss: 0.8272 - val_accuracy: 0.5898
# Epoch 37/100
# 35/35 [==============================] - 34s 981ms/step - loss: 0.6051 - accuracy: 0.7046 - val_loss: 0.8418 - val_accuracy: 0.5859
# Epoch 38/100
# 35/35 [==============================] - 34s 974ms/step - loss: 0.6320 - accuracy: 0.6902 - val_loss: 0.8340 - val_accuracy: 0.5898
# Epoch 39/100
# 35/35 [==============================] - 34s 972ms/step - loss: 0.6385 - accuracy: 0.6883 - val_loss: 0.8196 - val_accuracy: 0.5977
# Epoch 40/100
# 35/35 [==============================] - 34s 989ms/step - loss: 0.6144 - accuracy: 0.7001 - val_loss: 0.8240 - val_accuracy: 0.5977
# Epoch 41/100
# 35/35 [==============================] - 34s 977ms/step - loss: 0.5981 - accuracy: 0.7082 - val_loss: 0.9230 - val_accuracy: 0.5508
# Epoch 42/100
# 35/35 [==============================] - 34s 966ms/step - loss: 0.6014 - accuracy: 0.7073 - val_loss: 0.8171 - val_accuracy: 0.5977
# Epoch 43/100
# 35/35 [==============================] - 34s 984ms/step - loss: 0.5935 - accuracy: 0.7100 - val_loss: 0.8151 - val_accuracy: 0.6016
# Epoch 44/100
# 35/35 [==============================] - 34s 979ms/step - loss: 0.5935 - accuracy: 0.7109 - val_loss: 0.8552 - val_accuracy: 0.5781
# Epoch 45/100
# 35/35 [==============================] - 34s 985ms/step - loss: 0.6221 - accuracy: 0.6965 - val_loss: 0.8348 - val_accuracy: 0.5898
# Epoch 46/100
# 35/35 [==============================] - 34s 979ms/step - loss: 0.5958 - accuracy: 0.7100 - val_loss: 0.8014 - val_accuracy: 0.6094
# Epoch 47/100
# 35/35 [==============================] - 35s 997ms/step - loss: 0.5951 - accuracy: 0.7100 - val_loss: 0.8052 - val_accuracy: 0.6016
# Epoch 48/100
# 35/35 [==============================] - 35s 991ms/step - loss: 0.6215 - accuracy: 0.6974 - val_loss: 0.8498 - val_accuracy: 0.5820
# Epoch 49/100
# 35/35 [==============================] - 34s 974ms/step - loss: 0.6073 - accuracy: 0.7046 - val_loss: 0.8457 - val_accuracy: 0.5859
# Epoch 50/100
# 35/35 [==============================] - 34s 974ms/step - loss: 0.6010 - accuracy: 0.7073 - val_loss: 0.8870 - val_accuracy: 0.5625
# Epoch 51/100
# 35/35 [==============================] - 34s 992ms/step - loss: 0.6000 - accuracy: 0.7073 - val_loss: 0.8754 - val_accuracy: 0.5703
# Epoch 52/100
# 35/35 [==============================] - 35s 992ms/step - loss: 0.5933 - accuracy: 0.7118 - val_loss: 0.9241 - val_accuracy: 0.5469
# Epoch 53/100
# 35/35 [==============================] - 34s 974ms/step - loss: 0.6395 - accuracy: 0.6883 - val_loss: 0.8355 - val_accuracy: 0.5938
# Epoch 54/100
# 35/35 [==============================] - 34s 982ms/step - loss: 0.5923 - accuracy: 0.7127 - val_loss: 0.8553 - val_accuracy: 0.5781
# Epoch 55/100
# 14/35 [===========>..................] - ETA: 16s - loss: 0.5411 - accuracy: 0.7388

# %% [markdown]
# # Step 9: Look at the performance of the model change whilst training

# %%
loss = hist['loss']
val_loss = hist['val_loss']
acc = hist["accuracy"]
val_acc = hist["val_accuracy"]
epochs = range(len(val_acc))

plt.figure()
plt.title("Loss (training and validation)")
plt.ylabel("Loss")
plt.xlabel("Training Steps")

plt.ylim([0,2])
plt.plot(loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.legend()

plt.figure()
plt.title("Accuracy (training and validation)")
plt.ylabel("Accuracy")
plt.xlabel("Training Steps")

plt.ylim([0,1])
plt.plot(acc, 'r', label='Training Accuracy')
plt.plot(val_acc, 'b', label='Validation Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Step 10: Try out the model on an image from the validation data

# %%
def get_class_string_from_index(index):
   for class_string, class_index in valid_generator.class_indices.items():
      if class_index == index:
         return class_string

x, y = next(valid_generator)
image = x[0, :, :, :]
true_index = np.argmax(y[0])
plt.imshow(image)
plt.axis('off')
plt.show() 

# Expand the validation image to (1, 224, 224, 3) before predicting the label
prediction_scores = model.predict(np.expand_dims(image, axis=0))
predicted_index = np.argmax(prediction_scores)
print("True label: " + get_class_string_from_index(true_index))
print("Predicted label: " + get_class_string_from_index(predicted_index))
# Out:
# True label: Alluvial
# Predicted label: Alluvial

# %% [markdown]
# # Step 11: Plot confusion matrix

# %%
#Determining y_true for confusion matrix
num_ex = len(valid_generator.filenames)
num_of_generator_calls = math.ceil(num_ex / (1.0 * BATCH_SIZE))

test_labels = []

for i in range(0, int(num_of_generator_calls)):
    test_labels.extend(np.array(valid_generator[i][1]))

y_true = []
for i in range(0, num_ex):
  a = 0
  for j in range(4):
    if test_labels[i][j] == 0:
      a += 1
      continue
    else:
      break
  y_true.append(a)

# %%
#Determining y_pred for confusion matrix
predict = model.predict(valid_generator,num_ex)
pred = np.argmax(predict, axis=1)
y_pred = []

for i in range(len(pred)):
    y_pred.append(pred[i])

# %%
#confusion matrix
conf =  confusion_matrix(valid_generator.classes, y_pred)
# norm_conf = conf/conf.astype(np.float).sum(axis=1)

# %%
al=0
cl=0
red=0
bl=0
for i in range(4):
  for j in range(4):
    if i == 0:
      al += conf[i][j]
    elif i == 1:
      cl += conf[i][j]
    elif i == 2:
      red += conf[i][j]
    elif i == 3:
      bl += conf[i][j]

# %%
# initialize
conf_percent=np.zeros((4,4), np.float32)

for i in range(4):
  for j in range(4):
    if i == 0:
      conf_percent[i][j] = conf[i][j]/al
    elif i == 1:
      conf_percent[i][j] = conf[i][j]/cl
    elif i == 2:
      conf_percent[i][j] = conf[i][j]/red
    elif i == 3:
      conf_percent[i][j] = conf[i][j]/bl

# %%
classes = os.listdir(BASE_DATASET_PATH)
# classes = ['Alluvial', 'Clay', 'Latosol', 'Humus']
# plot confusion matrix
plt.imshow(conf_percent, interpolation='nearest', cmap=plt.cm.Greens)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = '0.3f'
thresh = conf_percent.max() / 2.
for i, j in itertools.product(range(conf_percent.shape[0]), range(conf_percent.shape[1])):
    plt.text(j, i, format(conf_percent[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf_percent[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 15.0, 'Predicted label')

# %% [markdown]
# #Step 11: TF Lite

# %%
saved_model_path = '/content/drive/Shareddrives/Nanem/model/model_download_baru_3/checkpoint'
# tf.saved_model.save(model, saved_model_path)
model.save(saved_model_path)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) mobilenetv2_1.00_224_input with unsupported characters which will be renamed to mobilenetv2_1_00_224_input in the SavedModel.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Nanem/model/model_download_baru_3/checkpoint/assets
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Nanem/model/model_download_baru_3/checkpoint/assets

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_path) # path to the SavedModel directory
tflite_model = converter.convert()

# Save the model.
with open(os.path.join('/content/drive/Shareddrives/Nanem/model/model_download_baru_3/tflite', 'model_4.tflite'), 'wb') as f:
  f.write(tflite_model)

# %%
#@title Optimization settings
optimize_lite_model = False  #@param {type:"boolean"}
#@markdown Setting a value greater than zero enables quantization of neural network activations. A few dozen is already a useful amount.
num_calibration_examples = 60  #@param {type:"slider", min:0, max:1000, step:1}
representative_dataset = None
if optimize_lite_model and num_calibration_examples:
  # Use a bounded number of training examples without labels for calibration.
  # TFLiteConverter expects a list of input tensors, each with batch size 1.
  representative_dataset = lambda: itertools.islice(
      ([image[None, ...]] for batch, _ in train_generator for image in batch),
      num_calibration_examples)

converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_path)
if optimize_lite_model:
  converter.optimizations = [tf.lite.Optimize.DEFAULT]
  if representative_dataset:  # This is optional, see above.
    converter.representative_dataset = representative_dataset
lite_model_content = converter.convert()

with open('/content/sample_data/model.tflite', "wb") as f:
  f.write(lite_model_content)
print("Wrote %sTFLite model of %d bytes." %
      ("optimized " if optimize_lite_model else "", len(lite_model_content)))
# Out:
# Wrote TFLite model of 9874668 bytes.

# %%
interpreter = tf.lite.Interpreter(model_content=lite_model_content)
# This little helper wraps the TF Lite interpreter as a numpy-to-numpy function.
def lite_model(images):
  interpreter.allocate_tensors()
  interpreter.set_tensor(interpreter.get_input_details()[0]['index'], images)
  interpreter.invoke()
  return interpreter.get_tensor(interpreter.get_output_details()[0]['index'])

# %%
#@markdown For rapid experimentation, start with a moderate number of examples.
num_eval_examples = 45  #@param {type:"slider", min:0, max:700}
eval_dataset = ((image, label)  # TFLite expects batch size 1.
                for batch in train_generator
                for (image, label) in zip(*batch))
count = 0
count_lite_tf_agree = 0
count_lite_correct = 0
for image, label in eval_dataset:
  probs_lite = lite_model(image[None, ...])[0]
  probs_tf = model(image[None, ...]).numpy()[0]
  y_lite = np.argmax(probs_lite)
  y_tf = np.argmax(probs_tf)
  y_true = np.argmax(label)
  count +=1
  if y_lite == y_tf: count_lite_tf_agree += 1
  if y_lite == y_true: count_lite_correct += 1
  if count >= num_eval_examples: break
print("TF Lite model agrees with original model on %d of %d examples (%g%%)." %
      (count_lite_tf_agree, count, 100.0 * count_lite_tf_agree / count))
print("TF Lite model is accurate on %d of %d examples (%g%%)." %
      (count_lite_correct, count, 100.0 * count_lite_correct / count))
# Out:
# TF Lite model agrees with original model on 172 of 172 examples (100%).
# TF Lite model is accurate on 159 of 172 examples (92.4419%).

# %% [markdown]
# # Soon to be erased: Saving, optimizing and deploying model

# %%
tf.saved_model.save(model,'/content/sample_data')

# %%
converter = tf.lite.TFLiteConverter.from_saved_model('/content/sample_data')
converter.optimizations = [tf.lite.Optimize.DEFAULT, tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]
tflite_quant_model = converter.convert()

# %%
#Save the model
with open('model.tflite', 'wb') as f:
  f.write(tflite_quant_model)

# %% [markdown]
# Soon to erase: HSV & Thresholding

# %%
# # Split dataset into training, validation, and testing with following ratio 0.8, 0.1, and 0.1
# import splitfolders
# splitfolders.ratio(BASE_PATH, output = OUTPUT_PATH, seed = 1092, ratio = (0.8, 0, 0.2), group_prefix = None)

# %%
# from IPython.display import clear_output

# # Simple progressBar to monitor progress :D
# # Credits: https://www.mikulskibartosz.name/how-to-display-a-progress-bar-in-jupyter-notebook/

# def updateProgressBar(progress, bar_length = 50):
#     if isinstance(progress, int):
#         progress = float(progress)
#     if not isinstance(progress, float):
#         progress = 0
#     if progress < 0:
#         progress = 0
#     if progress >= 1:
#         progress = 1

#     block = int(round(bar_length * progress))

#     # Clear current cell output 
#     clear_output(wait = True)
#     # Print progress!
#     print("Progress: [{0}] {1:.1f}%".format( "#" * block + "-" * (bar_length - block), progress * 100))

# %%
# #Munsell name MAGHEMITE 2.5YR 3/4
# rgb_alluvial = np.uint8([[[83,11,14]]])  # 3d array just because this is what cvtColor expects...
# hsv_alluvial = cv2.cvtColor(rgb_alluvial, cv2.COLOR_RGB2HSV)[0, 0, :]

# %%
# #Munsell name HUMUS 10YR 3/1
# rgb_black = np.uint8([[[42, 52, 50]]])  # 3d array just because this is what cvtColor expects...
# hsv_black = cv2.cvtColor(rgb_black, cv2.COLOR_RGB2HSV)[0, 0, :]

# %%
# #Munsell N 6/0
# rgb_clay = np.uint8([[[128,132,133]]])  # 3d array just because this is what cvtColor expects...
# hsv_clay = cv2.cvtColor(rgb_clay, cv2.COLOR_RGB2HSV)[0, 0, :]

# %%
# #Munsell 10R 3/6
# rgb_red = np.uint8([[[96,15,14]]])  # 3d array just because this is what cvtColor expects...
# hsv_red = cv2.cvtColor(rgb_red, cv2.COLOR_RGB2HSV)[0, 0, :]

# %%
# # Check output location
# if os.path.isdir(OUTPUT_PATH) == False:
#     os.mkdir(OUTPUT_PATH)

# num_files = 0
# cnt = 0

# for folder in os.listdir(BASE_PATH):
#   files = os.listdir(os.path.join(BASE_PATH, folder))
#    # Calculate num files for progress
#   num_files += len(files)
#   # Check output label folder exists
#   if os.path.exists(os.path.join(OUTPUT_PATH, folder)) == False:
#     os.mkdir(os.path.join(OUTPUT_PATH, folder))
#     print('folder output not found, create new!')

# # Iterate all image location
# for folder in os.listdir(BASE_PATH):
#   folder_path = os.path.join(BASE_PATH, folder)
#   if folder == 'alluvial':
#     #Munsell 2.5YR 2/3
#     lower_th = hsv_alluvial-np.array([46, 1, 8])
#     #Munsell 2.5YR 3/6
#     upper_th = hsv_alluvial+np.array([97, 20, 11])
  
#   elif folder == 'black':
#     #Munsell 10BG 2/1
#     lower_th = hsv_black-np.array([42, 49, 49])
#     #Munsell 5BG 5/1
#     upper_th = hsv_black+np.array([114, 126, 124])

#   elif folder == 'clay':
#     #Munsell N 4/0
#     lower_th = hsv_black-np.array([60, 65, 73])
#     #Munsell N 8/0
#     upper_th = hsv_black+np.array([195, 194, 189])
    

#   elif folder == 'red':
#     #Munsell 10R 3/2
#     lower_th = hsv_red-np.array([61,25,27])
#     #Munsell 10R 4/6
#     upper_th = hsv_red+np.array([116,28,20])

#   # Iterate all images at current folder location
#   for image in os.listdir(folder_path):
#     image_path = os.path.join(BASE_PATH, folder, image)
#     filename, ext = os.path.splitext(image_path)
#     if os.path.isfile(image_path) == False:
#       print('{}, not found, skipping...'.format(image))
#       continue
    
#     print('Processing image {} ...'.format(image))
#     image_read = cv2.imread(image_path)
#     image_hsv = cv2.cvtColor(image_read, cv2.COLOR_BGR2HSV)

#     # Threshold the HSV image
#     mask = cv2.inRange(image_hsv, lower_th, upper_th)
#     rgb_res = cv2.bitwise_and(image_read, image_read, mask = mask)

#     # Save Image
#     output_location = os.path.join(OUTPUT_PATH, folder, image)
#     cv2.imwrite(output_location, rgb_res)
#     print('Done Processed image {} at {}'.format(image, output_location))

#     cnt += 1
#     updateProgressBar(cnt / num_files)  

# updateProgressBar(1)
