# %% [markdown]
# <a href="https://colab.research.google.com/github/kimimumemo/nanem/blob/main/Nanem-onepicture-HSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to run in google colab
import numpy as np
import cv2
import os
from matplotlib import pyplot as plt

import sys
import glob
if 'google.colab' in sys.modules:
    import subprocess
    subprocess.call('apt-get install subversion'.split())
    subprocess.call('svn export https://github.com/YoniChechik/AI_is_Math/trunk/c_02a_basic_image_processing/grass.jpg'.split())
    subprocess.call('svn export https://github.com/YoniChechik/AI_is_Math/trunk/c_02a_basic_image_processing/hsv_th.png'.split())

# %%
figsize = (10, 10)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Split dataset into training, validation, and testing with following ratio 0.8, 0.1, and 0.1
import splitfolders
splitfolders.ratio(BASE_DATASET_PATH, output = , seed = 1092, ratio = (0.6, 0.2, 0.2), group_prefix = None)

# %%
BASE_PATH = '/content/drive/MyDrive/download_baru_2'
OUTPUT_PATH = '/content/drive/MyDrive/output_data'
rgb_red = np.uint8([[[255, 0, 0]]])  # 3d array just because this is what cvtColor expects...
hsv_red = cv2.cvtColor(rgb_red, cv2.COLOR_RGB2HSV)[0, 0, :]
# lower_th_red = 
lower_th = hsv_red-np.array([88, 65, 36])
upper_th = hsv_red+np.array([48, 28, 19])

for folder in os.listdir(BASE_PATH):
  for image in os.listdir(os.path.join(BASE_PATH, folder)):
    # if folder == 'red':
    #   lower = lower_th_red
    #   upper = upper_th_red
    # elif folder == 'black':
    #   lower = lower_th_black
    #   upper = upper_th_black
    image_path = os.path.join(BASE_PATH, folder, image)
    image = cv2.imread(image_path)
    image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    # Threshold the HSV image
    mask = cv2.inRange(image_hsv, lower_th, upper_th)
    rgb_res = cv2.bitwise_and(rgb_im, rgb_im, mask=mask)
    # Save Image
    cv2.imwrite(os.path.join(OUTPUT_PATH, folder, image), rgb_res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-f7f06da985c8> in <module>()
#      20     # Threshold the HSV image
#      21     mask = cv2.inRange(image_hsv, lower_th, upper_th)
# ---> 22     rgb_res = cv2.bitwise_and(rgb_im, rgb_im, mask=mask)
#      23     # Save Image
#      24     cv2.imwrite(os.path.join(OUTPUT_PATH, folder, image), rgb_res)
#
# NameError: name 'rgb_im' is not defined

# %%
for i in range(1,3):
  img_path = '/content/grass' + str(i) + '.jpg'
  img = cv2.imread(img_path)
  print(img)

# %%
bgr_im = cv2.imread("grass.jpg")
rgb_im = cv2.cvtColor(bgr_im, cv2.COLOR_BGR2RGB)
plt.figure(figsize=figsize)
plt.imshow(rgb_im)
plt.title("original image")

# %%
rgb_red = np.uint8([[[255, 0, 0]]])  # 3d array just because this is what cvtColor expects...
hsv_red = cv2.cvtColor(rgb_red, cv2.COLOR_RGB2HSV)[0, 0, :]
print(hsv_red)
# Out:
# [  0 255 255]

# %%
thresholding_schematics = cv2.cvtColor(cv2.imread("hsv_th.png"), cv2.COLOR_BGR2RGB)
plt.figure(figsize=figsize)
plt.imshow(thresholding_schematics)
plt.title("Thresholding schematics")
# Out:
# Text(0.5, 1.0, 'Thresholding schematics')

# %%
# Convert BGR to HSV
hsv_im = cv2.cvtColor(rgb_im, cv2.COLOR_RGB2HSV)

# define range of hue and intensity
lower_th = hsv_red-np.array([88, 65, 36])
upper_th = hsv_red+np.array([48, 28, 19])

# Threshold the HSV image
mask = cv2.inRange(hsv_im, lower_th, upper_th)

plt.figure(figsize=figsize)
plt.imshow(mask)
plt.title("resulted mask")
# Out:
# Text(0.5, 1.0, 'resulted mask')

# %%
rgb_res = cv2.bitwise_and(rgb_im, rgb_im, mask=mask)

plt.figure(figsize=figsize)
plt.imshow(rgb_res)
plt.title("output image")
plt.show()
